# %% [markdown]
# <a href="https://colab.research.google.com/github/tk1981215/Machine-Learning/blob/main/Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([3000,3500,4000,4500,5000])
model = LinearRegression()
model.fit(X,y)
prediction = model.predict([[6]])
print("Model Prediction : " , prediction)

plt.scatter(X,y)
plt.plot(X,model.predict(X))
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()
# Out:
# Model Prediction :  [5500.]
